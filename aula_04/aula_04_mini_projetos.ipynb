# %% [markdown]
# > # **Mini Projetos de Revisão - Aula 04**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ry4n-felinto/impytech_2026/blob/main/aula_04/aula_04_mini_projetos.ipynb)
#
# - **Professor:** Ryan Kevin
#   - al.ryan.felinto@impatech.edu.br
#
# - **Monitores:**
#   - Bianca Zavadisk (al.bianca.abreu@impatech.edu.br)
#   - Bruno Paula (al.bruno.paula@impatech.edu.br)
#   - Pedro Alberti (al.pedro.alberti@impatech.edu.br)
#   - Cristiane Sampaio (al.cristiane.sampaio@impatech.edu.br)
#
# - **Desenvolvedores:**
#    - Bianca Zavadisk de Abreu
#       - al.bianca.abreu@impatech.edu.br
#
#  ## **Revisão de Sintaxe Básica com Mini Projetos na Área de Saúde**
#
# ---

# %% [markdown]
# > ## **Projeto 1 - Sistema de Triagem Clínica e Sinais Vitais** 🟢 🟡
# Em um serviço de pronto-atendimento ou triagem de ensaio clínico, a automação do fluxo de classificação dos sinais vitais acelera a identificação de pacientes graves. Neste projeto, você construirá gradualmente um **pipeline automatizado de triagem** analisando Pressão Arterial, Saturação de Oxigênio ($SpO_2$) e **Níveis de Glicemia**, além de manipular a persistência de dados em **arquivos externos (`.txt`)**.
#
# **Conceitos praticados:** Variáveis, Condicionais (`if/elif/else`), Funções, Listas, Dicionários, Loops (`for`) e Manipulação de Arquivos (`open/read/write`).

# %% [markdown]
# ### 📝 **Problema 1.1 — Classificação Isolada da Pressão Arterial** 🟢
# Antes de criar uma função completa, vamos construir a lógica de classificação de pressão arterial para um único par de valores.
#
# Dadas as variáveis `sistolica` e `diastolica`, escreva uma estrutura condicional (`if/elif/else`) para definir o valor da variável `categoria_pa` segundo a tabela:
# - **"Normal"**: Sistólica < 120 e Diastólica < 80
# - **"Elevada"**: Sistólica entre 120 e 129 e Diastólica < 80
# - **"Hipertensão 1"**: Sistólica entre 130 e 139 ou Diastólica entre 80 e 89
# - **"Hipertensão 2"**: Sistólica >= 140 ou Diastólica >= 90
#
# **🎯 Objetivo:** Escrever o bloco de condicionais isolado. <br>
# **📥 Exemplo de Entrada:** `sistolica = 135`, `diastolica = 85` <br>
# **📤 Exemplo de Saída:** Imprimir: `Categoria PA: Hipertensão 1`

# %%
sistolica = 135
diastolica = 85

# Desenvolva as condicionais para definir a variável categoria_pa:
categoria_pa = ""

# Imprima o resultado:
print(f"Categoria PA: {categoria_pa}")

# %% [markdown]
# ### 📝 **Problema 1.2 — Verificação do Risco de Hipóxia ($SpO_2$)** 🟢
# A saturação de oxigênio ($SpO_2$) é outro indicador essencial na triagem. Escreva um bloco condicional simples que verifique o valor da variável `spo2`:
# - Se `spo2 < 93`: defina `alerta_oxigenio = True`
# - Caso contrário: defina `alerta_oxigenio = False`
#
# **🎯 Objetivo:** Testar a verificação da saturação em um bloco isolado. <br>
# **📥 Exemplo de Entrada:** `spo2 = 91` <br>
# **📤 Exemplo de Saída:** Imprimir: `Alerta Oxigênio: True`

# %%
spo2 = 91

# Escreva a condicional para atribuir True ou False a alerta_oxigenio:
alerta_oxigenio = False

print(f"Alerta Oxigênio: {alerta_oxigenio}")

# %% [markdown]
# ### 📝 **Problema 1.3 — Classificação dos Níveis de Glicemia** 🟢
# A medição de glicemia em jejum/triagem rápida ajuda na identificação imediata de crises metabólicas. Escreva um bloco condicional que avalie a variável `glicemia` (mg/dL) e defina a variável `categoria_glicemia` conforme as regras:
# - **"Hipoglicemia"**: `glicemia < 70`
# - **"Normal"**: `70 <= glicemia <= 99`
# - **"Alterada"**: `100 <= glicemia <= 125`
# - **"Hiperglicemia"**: `glicemia >= 126`
#
# **🎯 Objetivo:** Classificar o nível glicêmico do paciente em um bloco isolado.<br>
# **📥 Exemplo de Entrada:** `glicemia = 140` <br>
# **📤 Exemplo de Saída:** Imprimir: `Categoria Glicemia: Hiperglicemia`

# %%
glicemia = 140

# Escreva a condicional para definir a variável categoria_glicemia:
categoria_glicemia = ""

print(f"Categoria Glicemia: {categoria_glicemia}")

# %% [markdown]
# ### 📝 **Problema 1.4 — Função Integrada de Triagem Clínica** 🟡
# Unifique a lógica dos problemas **1.1**, **1.2** e **1.3** em uma função reutilizável chamada `triar_paciente(sistolica, diastolica, spo2, glicemia)`.
#
# A função deve retornar uma **tupla** no formato `(categoria_pa, categoria_glicemia, prioridade_emergencia)`:
# - `categoria_pa`: String calculada no item 1.1.
# - `categoria_glicemia`: String calculada no item 1.3.
# - `prioridade_emergencia`: Booleano (`True`/`False`), que será `True` se **qualquer uma** das condições críticas for atendida:
#   - `categoria_pa == "Hipertensão 2"`
#   - `spo2 < 93`
#   - `glicemia < 70` ou `glicemia >= 200`
#
# **🎯 Objetivo:** Encapsular os 3 parâmetros vitais em uma função de decisão clínica.<br>
# **📥 Exemplo de Entrada:** `triar_paciente(145, 92, 96, 110)` <br>
# **📤 Exemplo de Saída:** `('Hipertensão 2', 'Alterada', True)`

# %%
def triar_paciente(sistolica, diastolica, spo2, glicemia):
    # 1. Determine categoria_pa
    # 2. Determine categoria_glicemia
    # 3. Avalie se prioridade_emergencia é True ou False
    # 4. Retorne (categoria_pa, categoria_glicemia, prioridade_emergencia)
    pass

# Teste sua função:
print(triar_paciente(145, 92, 96, 110))

# %% [markdown]
# ### 📝 **Problema 1.5 — Processamento da Fila de Espera em Memória** 🟡
# Utilize a função `triar_paciente()` para iterar sobre uma lista de dicionários contendo os dados dos atendimentos.
#
# Utilize um loop `for` para percorrer a `fila_pacientes` e imprima na tela o nome, as categorias e o alerta de emergência de cada um.
#
# **🎯 Objetivo:** Processar múltiplos registros de dados estruturados em memória.

# %%
fila_pacientes = [
    {"nome": "Ana Silva", "pa": (118, 76), "spo2": 98, "glicemia": 92},
    {"nome": "Carlos Souza", "pa": (145, 92), "spo2": 95, "glicemia": 140},
    {"nome": "Mariana Lima", "pa": (124, 78), "spo2": 91, "glicemia": 65},
    {"nome": "João Pedro", "pa": (135, 88), "spo2": 97, "glicemia": 210}
]

# Escreva o loop de processamento aqui:

# %% [markdown]
# ---
# ### 🚀 **Problema 1.6: Desafio Extra — Pipeline de Entrada e Saída (E/S) em Arquivos** 🟡 🔴
#
# Agora que temos a lógica clínica construída, vamos integrá-la a arquivos externos de texto (`.txt`).

# %% [markdown]
# #### 📝 **Problema 1.6.1 — Passo 1: Leitura e Exibição do Arquivo** 🟢
# Antes de processar os dados, abra o arquivo `pacientes_triagem.txt`, leia todo o seu conteúdo e exiba-o diretamente na tela para verificar se o arquivo está acessível.
#
# **🎯 Objetivo:** Utilizar o bloco `with open()` com o modo de leitura `'r'` e imprimir cada linha na tela.

# %%
# 1. Abra o arquivo 'pacientes_triagem.txt' em modo de leitura ('r')
# 2. Percorra e imprima todas as linhas na tela:
with open('pacientes_triagem.txt', 'r', encoding='utf-8') as arquivo:
    for linha in arquivo:
        print(linha.strip())

# %% [markdown]
# #### 📝 **Problema 1.6.2 — Passo 2: *Parsing* dos Dados e Construção de Dicionários** 🟡
# Agora vamos estruturar os dados lidos do arquivo.
#
# **Tarefas:**
# 1. Abra o arquivo `pacientes_triagem.txt` novamente.
# 2. **Ignore/pule a primeira linha** (cabeçalho).
# 3. Para cada linha seguinte, remova os espaços/quebras de linha, divida as colunas pela vírgula (`split(',')`) e converta os tipos de dados:
#    - `sistolica`, `diastolica`, `spo2` e `glicemia` devem virar números inteiros (`int`).
# 4. Crie um dicionário para cada paciente e adicione-o à lista `pacientes_estruturados`.

# %%
pacientes_estruturados = []

with open('pacientes_triagem.txt', 'r', encoding='utf-8') as arquivo:
    linhas = arquivo.readlines()
    
    # Pule o cabeçalho (linhas[1:]) e construa a lista de dicionários:
    for linha in linhas[1:]:
        if not linha.strip():
            continue
        
        # Desenvolva o split e a montagem do dicionário aqui:
        pass

# Imprima a lista gerada para conferir o resultado:
print(pacientes_estruturados)

# %% [markdown]
# #### 📝 **Problema 1.6.3 — Passo 3: Triagem Automatizada com a Função Anterior** 🟡
# Com a lista `pacientes_estruturados` pronta, utilize um loop `for` para aplicar a função `triar_paciente()` (desenvolvida no **Problema 1.4**) em cada paciente.
#
# **🎯 Objetivo:** Adicionar o resultado da triagem `(categoria_pa, categoria_glicemia, prioridade_emergencia)` como novas chaves no dicionário de cada paciente ou exibi-los formatados na tela.

# %%
# Percorra a lista pacientes_estruturados e aplique triar_paciente():
for p in pacientes_estruturados:
    # Chame a função triar_paciente passando os parâmetros do dicionário:
    # pa_cat, glic_cat, emerg = triar_paciente(p['sistolica'], p['diastolica'], p['spo2'], p['glicemia'])
    pass

# %% [markdown]
# #### 📝 **Problema 1.6.4 — Passo 4: Escrita do Relatório Final (`relatorio_emergencia.txt`)** 🟡
# Para finalizar o pipeline, crie um novo arquivo chamado `relatorio_emergencia.txt` no modo de escrita (`'w'`).
#
# **O arquivo deve conter:**
# 1. Um cabeçalho formatado para a equipe médica.
# 2. Uma linha para cada paciente com o nome e se ele foi classificado em **EMERGÊNCIA** (`SIM`/`NÃO`).
# 3. Um resumo ao final informando a quantidade **total de emergências** encontradas.

# %%
# Escreva os dados no arquivo 'relatorio_emergencia.txt':
with open('relatorio_emergencia.txt', 'w', encoding='utf-8') as f_out:
    f_out.write("=== RELATÓRIO FINAL DE TRIAGEM CLÍNICA ===\n\n")
    
    total_emergencias = 0
    
    # Desenvolva a escrita dos dados e a contagem de emergências aqui:
    
print("Relatório gerado com sucesso em 'relatorio_emergencia.txt'!")

# %% [markdown]
# ---

# %% [markdown]
# > ## **Projeto 2 - Análise Biomédica e Controle de Qualidade Genômica (DNA/RNA)** 🟡
# Na biologia molecular e genômica, a validação de sequências de DNA é indispensável. O **Conteúdo GC** (% de Guanina e Citosina) indica a estabilidade térmica do DNA, enquanto a presença de caracteres inválidos (como a letra `'N'`) indica falhas no sequenciamento. Neste projeto, você construirá um módulo de controle de qualidade de sequências.
#
# Fórmula do Conteúdo GC:
# $$GC\% = \frac{\text{Qtd de G} + \text{Qtd de C}}{\text{Tamanho da Sequência}} \times 100$$
#
# **Conceitos praticados:** Manipulação de Strings, Loops, Funções, Dicionários e Tratamento de Erros Lógicos.

# %% [markdown]
# ### 📝 **Problema 2.1 — Calculadora do Conteúdo GC** 🟢
# Escreva um trecho de código que receba uma string de DNA (ex: `dna = "ATGCGATCG"`), converta-a para maiúsculas com `.upper()` e calcule a porcentagem de bases G e C em relação ao tamanho total da sequência.
#
# **🎯 Objetivo:** Escrever o cálculo do percentual em código isolado.<br>
# **📥 Exemplo de Entrada:** `dna = "ATGC"` <br>
# **📤 Exemplo de Saída:** `50.0`

# %%
dna = "ATGCGATCG"

# Calcule o teor GC do DNA acima:
porcentagem_gc = 0.0

print(f"Conteúdo GC: {porcentagem_gc:.2f}%")

# %% [markdown]
# ### 📝 **Problema 2.2 — Validador de Integridade de Sequência** 🟡
# Em dados brutos de sequenciamento, bases desconhecidas são representadas pela letra `'N'`.
#
# Escreva um código que receba uma sequência de DNA e verifique se ela contém qualquer caractere diferente das 4 bases nitrogenadas padrão (`'A'`, `'T'`, `'G'`, `'C'`). O resultado deve ser a variável booleana `sequencia_valida` (`True` se contiver apenas A, T, G, C; `False` caso contrário).
#
# **🎯 Objetivo:** Implementar verificação de caracteres inválidos em strings.<br>
# **📥 Exemplo de Entrada:** `dna = "ATGCNDTCG"` <br>
# **📤 Exemplo de Saída:** `Sequência Válida: False`

# %%
dna_amostra = "ATGCNDTCG"

# Verifique se a sequência é válida (somente A, T, G, C):
sequencia_valida = True

print(f"Sequência Válida: {sequencia_valida}")

# %% [markdown]
# ### 📝 **Problema 2.3 — Função Integrada de Análise de Qualidade Genômica** 🟡
# Combine os passos **2.1** e **2.2** em uma função chamada `analisar_amostra_dna(dna_sequence)`.
#
# A função deve retornar um **dicionário** com a seguinte estrutura:
# - `'valida'`: Booleano indicando integridade da sequência (código do 2.2).
# - `'tamanho'`: Inteiro indicando o tamanho do fragmento.
# - `'gc_pct'`: Se a sequência for **válida**, retorne o % GC arredondado para 2 casas decimais. Se for **inválida**, retorne `None`.
#
# **🎯 Objetivo:** Construir uma função que avalia e estrutura métricas de qualidade.

# %%
def analisar_amostra_dna(dna_sequence):
    # Desenvolva a função utilizando a lógica dos exercícios anteriores
    pass

# %%
# Teste com amostra válida:
print(analisar_amostra_dna("ATGCGATCGT"))

# Teste com amostra inválida:
print(analisar_amostra_dna("ATGCNGATCGT"))

# %% [markdown]
# ### 📝 **Problema 2.4 — Relatório de Lote de Amostras biomédicas** 🟡
# Sua equipe de bancada enviou um lote de amostras registradas em um dicionário de sequências.
#
# Itere sobre este dicionário, aplique a função `analisar_amostra_dna()` para cada amostra e imprima um relatório separando as **Amostras Aprovadas para PCR** (válidas e com GC % entre 40% e 60%) das **Amostras Descartadas**.
#
# **🎯 Objetivo:** Filtrar e categorizar dados utilizando dicionários e a função desenvolvida.

# %%
lote_dna = {
    "Amostra_01": "ATGCGATCGATCG",
    "Amostra_02": "ATGNATATATA",
    "Amostra_03": "GCGCGCGCGC",
    "Amostra_04": "ATGCATGCATN"
}

# Escreva o código de filtragem e geração de relatório do lote aqui:

# %% [markdown]
# ---
# ### 🚀 **Problema 2.5: Desafio Extra — Pipeline de Bioinformática com Arquivos (`.txt`)** 🟡 🔴
#
# Em rotinas de sequenciamento genômico de alto desempenho, as sequências de DNA chegam diretamente em arquivos texto. Vamos construir um pipeline automatizado para ler o lote, validar a integridade e salvar os resultados.

# %% [markdown]
# #### 📝 **Problema 2.5.1 — Passo 1: Leitura e Inspeção de Sequências Brutas** 🟢
# Abra o arquivo `sequencias_dna.txt` em modo de leitura (`'r'`), leia e imprima todas as linhas brutas na tela para validar a leitura dos dados de sequenciamento.
#
# **🎯 Objetivo:** Abrir o arquivo de dados genômicos e listar o conteúdo bruto.

# %%
# 1. Abra o arquivo 'sequencias_dna.txt' em modo de leitura ('r')
# 2. Percorra e imprima todas as linhas na tela:
with open('sequencias_dna.txt', 'r', encoding='utf-8') as arquivo:
    for linha in arquivo:
        print(linha.strip())

# %% [markdown]
# #### 📝 **Problema 2.5.2 — Passo 2: Parsing das Sequências para Dicionário** 🟡
# Agora vamos transformar o texto bruto em uma estrutura manipulável no Python.
#
# **Tarefas:**
# 1. Abra o arquivo `sequencias_dna.txt`.
# 2. **Ignore/pule a primeira linha** (cabeçalho `id_amostra,sequencia`).
# 3. Para cada linha restante, separe o ID da Amostra e a Sequência de DNA utilizando `.split(',')` e `.strip()`.
# 4. Armazene os pares em um dicionário chamado `lote_arquivo` no formato `{"ID_AMOSTRA": "SEQUENCIA"}`.

# %%
lote_arquivo = {}

with open('sequencias_dna.txt', 'r', encoding='utf-8') as arquivo:
    linhas = arquivo.readlines()
    
    # Pule o cabeçalho e preencha o dicionário lote_arquivo:
    for linha in linhas[1:]:
        if not linha.strip():
            continue
        
        # Desenvolva a separação e inclusão no dicionário aqui:
        pass

# Imprima o dicionário criado para conferir:
print(lote_arquivo)

# %% [markdown]
# #### 📝 **Problema 2.5.3 — Passo 3: Avaliação de Controle de Qualidade (QC)** 🟡
# Com o dicionário `lote_arquivo` preenchido, utilize a função `analisar_amostra_dna()` (desenvolvida no **Problema 2.3**) para avaliar cada amostra.
#
# Classifique cada amostra nas categorias de bancada:
# - **Aprovada para PCR:** Sequência **válida** E com **% GC entre 40% e 60%**.
# - **Descartada:** Sequência **inválida** (contém `'N'`) OU **% GC fora do intervalo** (menor que 40% ou maior que 60%).
#
# **🎯 Objetivo:** Processar o dicionário lido do arquivo e classificar o status biomédico de cada sequência.

# %%
# Percorra o dicionário lote_arquivo e aplique analisar_amostra_dna():
for amostra_id, dna_seq in lote_arquivo.items():
    # resultado = analisar_amostra_dna(dna_seq)
    # Implemente a lógica de avaliação aqui:
    pass

# %% [markdown]
# #### 📝 **Problema 2.5.4 — Passo 4: Escrita do Laudo Biomédico (`relatorio_qualidade_dna.txt`)** 🟡
# Para finalizar a automação do laboratório, crie um novo arquivo chamado `relatorio_qualidade_dna.txt` no modo de escrita (`'w'`).
#
# **O arquivo gerado deve conter:**
# 1. Um cabeçalho formal do laboratório de genômica.
# 2. Uma lista com o ID da amostra, o % GC calculado e a decisão (`Aprovada para PCR` / `Descartada`).
# 3. Um sumário ao final indicando o **total de amostras aprovadas** e o **total de amostras descartadas**.

# %%
# Escreva o laudo no arquivo 'relatorio_qualidade_dna.txt':
with open('relatorio_qualidade_dna.txt', 'w', encoding='utf-8') as f_out:
    f_out.write("=== LAUDO DE CONTROLE DE QUALIDADE GENÔMICA ===\n\n")
    
    total_aprovadas = 0
    total_descartadas = 0
    
    # Desenvolva o loop de processamento e escrita no arquivo aqui:
    
print("Laudo genômico gerado com sucesso em 'relatorio_qualidade_dna.txt'!")

# %% [markdown]
# > ## **Projeto 3 - Processamento e Análise de Sinais de Eletrocardiograma (ECG)** 🟡 🔴
# Um Eletrocardiograma (ECG) registra a atividade elétrica cardíaca. Um dos parâmetros fundamentais extraídos desses exames é o **Intervalo R-R** (tempo em milissegundos entre dois picos de batimento consecutivos).
#
# Neste projeto, você vai desenvolver um algoritmo para ler sequências temporais de picos R-R, converter os tempos em Frequência Cardíaca (BPM), checar a variabilidade do ritmo e diagnosticar potenciais arritmias ou anomalias.
#
# **Conceitos praticados:** Listas, Operações com Sequências Temporais, Funções, Condicionais e Dicionários.

# %% [markdown]
# ### 📝 **Problema 3.1 — Conversor de Intervalo R-R em Batimentos Por Minuto (BPM)** 🟡
# A conversão de um único intervalo R-R (em ms) para a Frequência Cardíaca pontual (BPM) é dada por:
# $$\text{BPM} = \frac{60000}{\text{Intervalo R-R (ms)}}$$
#
# Escreva um código simples que receba um valor `intervalo_rr = 800` e calcule o BPM correspondente.
#
# **🎯 Objetivo:** Realizar a conversão matemática básica de sinal temporal.<br>
# **📥 Exemplo de Entrada:** `intervalo_rr = 800` <br>
# **📤 Exemplo de Saída:** `75.0`

# %%
intervalo_rr = 800

# Calcule o bpm correspondente:
bpm = 0.0

print(f"Frequência pontual: {bpm:.1f} BPM")

# %% [markdown]
# ### 📝 **Problema 3.2 — Média de BPM e Detecção de Oscilações Brutas** 🟡
# Em um registro contínuo de ECG, recebemos uma **lista de intervalos R-R**.
#
# Dada a lista `sinal_rr = [800, 810, 790, 820, 800]`, escreva um código usando um loop `for` que:
# 1. Calcule a média dos intervalos R-R da lista e a converta para **BPM médio**.
# 2. Calcule a maior variação (diferença) entre dois batimentos consecutivos na lista.
#
# **🎯 Objetivo:** Processar listas numéricas sequenciais e calcular métricas de variação.<br>
# **📥 Exemplo de Entrada:** `sinal_rr = [800, 810, 790, 820, 800]`

# %%
sinal_rr = [800, 810, 790, 820, 800]

# 1. Calcule o BPM médio da lista:
bpm_medio = 0.0

# 2. Calcule a maior variação absoluta entre batimentos consecutivos:
maior_variacao = 0

print(f"BPM Médio: {bpm_medio:.1f}")
print(f"Maior variação consecutiva: {maior_variacao} ms")

# %% [markdown]
# ### 📝 **Problema 3.3 — Função Integrada de Diagnóstico de ECG** 🟡 🔴
# Encapsule a lógica desenvolvida nos itens **3.1** e **3.2** em uma função chamada `diagnosticar_ecg(intervalos_rr)`.
#
# A função deve retornar uma **string** indicando a condição cardíaca do paciente com base nos critérios:
# - **"Bradicardia"**: Se BPM médio < 60
# - **"Taquicardia"**: Se BPM médio > 100
# - **"Suspeita de Arritmia / Instabilidade"**: Se o BPM médio for normal (entre 60 e 100), mas a maior variação consecutiva entre dois intervalos R-R for **maior que 120 ms**.
# - **"Ritmo Sinusal Normal"**: Se BPM estiver entre 60 e 100 e a variação for <= 120 ms.
#
# **🎯 Objetivo:** Integrar a análise de séries numéricas e tomadas de decisão compostas numa função.

# %%
def diagnosticar_ecg(intervalos_rr):
    # Desenvolva a função aqui
    pass

# Testes:
print("Sinal 1:", diagnosticar_ecg([800, 810, 790, 800]))
print("Sinal 2:", diagnosticar_ecg([800, 620, 850, 600]))
print("Sinal 3:", diagnosticar_ecg([1200, 1150, 1180, 1210]))

# %% [markdown]
# ### 📝 **Problema 3.4 — Módulo de Processamento de Holter Cardiológico** 🔴
# Em um monitoramento do tipo Holter 24h, o sistema registra vários exames. Você recebeu um dicionário com os registros de exames de 4 pacientes.
#
# Escreva um programa que percorra esse dicionário, utilize a função `diagnosticar_ecg()` e exiba o laudo individual de cada paciente.
#
# **🎯 Objetivo:** Automatizar o processamento de múltiplos sinais de exames em lote.

# %%
exames_holter = {
    "Paciente_01": [800, 810, 795, 805, 810],
    "Paciente_02": [500, 480, 510, 490, 505],
    "Paciente_03": [1150, 1100, 1120, 1180, 1140],
    "Paciente_04": [800, 650, 820, 640, 810]
}

# Desenvolva o laudo para cada paciente do dicionário:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Projeto 4 - Aplicação Prática na Sua Pesquisa**
# Agora é a sua vez! O objetivo da programação na área da saúde e ciências biomédicas é automatizar rotinas reais do seu dia a dia de trabalho de laboratório, análise de dados de bancada ou prontuários.
#
# Pense em uma tarefa simples da sua rotina de pesquisa (ex: conversão de unidades de reagentes, calculo de dosagem por peso de camundongos, triagem de dados de citometria, cálculo de médias de triplicatas de PCR, etc.).

# %% [markdown]
# ### 📝 **Problema 4.1 — Desenvolva a sua solução** 🌟
# Escreva abaixo um algoritmo em Python focado na resolução de um problema real do seu projeto de pesquisa. Seu código deve obrigatoriamente conter **pelo menos 3** dos seguintes elementos:
# - [ ] Definição e chamada de **Funções**
# - [ ] Estrutura condicional (`if/elif/else`)
# - [ ] Estrutura de repetição (**Loops** `for` ou `while`)
# - [ ] Estrutura de dados (**Listas, Dicionários ou Tuplas**)
#
# **🎯 Objetivo:** Aplicar o conhecimento revisado diretamente no seu contexto científico. <br>
# *Adicione um comentário (`#`) nas primeiras linhas explicando qual problema o script resolve.*

# %%
# [DESCREVA O SEU PROBLEMA DE PESQUISA AQUI]
# Exemplo: Algoritmo para calcular diluição de anticorpos baseada na concentração inicial.

# Seu código aqui:

# %% [markdown]
# ---
