# %% [markdown]
# > # **Exercícios - Python Aplicado à Saúde**
#
#  ## **Lista de Desafios**
#
# ---

# %% [markdown]
# > ## **Problema 1 - Cadastro de Pacientes** 🟡
# Você trabalha no setor de registro de uma clínica e é responsável por cadastrar todos os pacientes que chegam para atendimento. Cada paciente deve possuir uma ficha contendo informações pessoais e antropométricas, que serão utilizadas posteriormente para consultas e análises estatísticas. Cada ficha deve conter: Código (iniciando em 01 e incrementado), Nome completo, Idade, Sexo ("Masculino" ou "Feminino"), Peso (em quilogramas) e Altura (em metros).
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **Problema 1.1**
# Desenvolva um programa que solicite ao usuário todas as informações de um único paciente e exiba a ficha completa de forma organizada e formatada.
#
# **🎯 Objetivo:** Solicitar dados via terminal e exibir as informações estruturadas na tela.<br>

# %%
# Área de código para o problema 1.1:

# %% [markdown]
# ### 📝 **Problema 1.2**
# Modifique o programa anterior para permitir o cadastro de cinco pacientes diferentes, armazenando todas as fichas para uso posterior.
#
# **🎯 Objetivo:** Utilizar estruturas de repetição e armazenamento para múltiplos pacientes.<br>

# %%
# Área de código para o problema 1.2:

# %% [markdown]
# ### 📝 **Problema 1.3**
# Utilizando as cinco fichas cadastradas anteriormente, desenvolva um programa capaz de apresentar as seguintes informações: Quantidade total, idade média, quantidade por sexo, paciente com maior peso e paciente com menor altura.
#
# **🎯 Objetivo:** Extrair dados estatísticos e encontrar valores extremos na base armazenada.<br>

# %%
# Área de código para o problema 1.3:

# %% [markdown]
# ### 📝 **Problema 1.4**
# Aprimore o programa desenvolvido no item 1.2, permitindo o cadastro de uma quantidade indeterminada de pacientes. O encerramento do cadastro deverá ocorrer apenas quando o usuário desejar finalizar o processo.
#
# **🎯 Objetivo:** Implementar um loop baseado em condição de parada definida pelo usuário.<br>

# %%
# Área de código para o problema 1.4:

# %% [markdown]
# ### 📝 **Problema 1.5**
# Desenvolva um programa que permita consultar a ficha de um paciente a partir do seu código de identificação. Todas as informações cadastradas deverão ser exibidas de forma organizada e formatada.
#
# **🎯 Objetivo:** Implementar um mecanismo de busca em uma base de dados previamente populada.<br>

# %%
# Área de código para o problema 1.5:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 2 - Registro de Diagnósticos** 🟡
# Após realizar o cadastro dos pacientes, a clínica deseja automatizar parte do processo de triagem. Para isso, o sistema deverá receber algumas informações sobre os sintomas apresentados pelo paciente e sugerir um diagnóstico e recomendação terapêutica. (Observação: Uso exclusivamente didático).
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **Problema 2.1**
# Desenvolva um programa que pergunte ao usuário a presença ou ausência de três sintomas definidos na tabela fornecida. Ao final, o programa deverá indicar o diagnóstico correspondente.
#
# **🎯 Objetivo:** Utilizar operadores lógicos e condicionais para tomada de decisão.<br>

# %%
# Área de código para o problema 2.1:

# %% [markdown]
# ### 📝 **Problema 2.2**
# Utilizando o diagnóstico obtido no item anterior, desenvolva um programa que recomende uma medicação fictícia de acordo com a tabela disponibilizada.
#
# **🎯 Objetivo:** Mapear um resultado (diagnóstico) para uma saída específica (medicação).<br>

# %%
# Área de código para o problema 2.2:

# %% [markdown]
# ### 📝 **Problema 2.3**
# Considere que a dosagem da medicação depende das características do paciente. Utilizando uma tabela fornecida, desenvolva um programa que determine a dosagem recomendada com base na idade, sexo, peso e altura do paciente.
#
# **🎯 Objetivo:** Combinar múltiplos critérios de entrada em uma lógica condicional composta.<br>

# %%
# Área de código para o problema 2.3:

# %% [markdown]
# ### 📝 **Problema 2.4**
# Desenvolva um programa que registre todas as informações do paciente em uma ficha contendo nome, sexo, idade, peso, altura, sintomas informados, diagnóstico, medicação e dosagem.
#
# **🎯 Objetivo:** Agrupar todos os dados processados em uma única estrutura unificada.<br>

# %%
# Área de código para o problema 2.4:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 3 - Monitoramento da Frequência Cardíaca** 🟡
# Durante um estudo sobre qualidade do sono, um paciente utilizou um monitor cardíaco que registra a frequência média a cada minuto. O equipamento iniciou às 00h00 e rodou continuamente até ele acordar.
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **Problema 3.1**
# Desenvolva um programa que receba o horário em que o monitor foi desligado e informe por quanto tempo o equipamento permaneceu ligado, apresentando o resultado em horas e minutos.
#
# **🎯 Objetivo:** Realizar cálculos envolvendo conversão de horas e minutos.<br>

# %%
# Área de código para o problema 3.1:

# %% [markdown]
# ### 📝 **Problema 3.2**
# Considerando a lista contendo todas as frequências cardíacas registradas, desenvolva um programa que determine a frequência média, a maior e a menor frequência.
#
# **🎯 Objetivo:** Aplicar funções matemáticas sobre listas para obtenção de médias e extremos.<br>

# %%
# Área de código para o problema 3.2:

# %% [markdown]
# ### 📝 **Problema 3.3**
# Episódios de taquicardia correspondem a frequências superiores a 100 bpm. Desenvolva um programa que percorra os registros e informe quantos minutos de taquicardia foram identificados e os horários de ocorrência.
#
# **🎯 Objetivo:** Filtrar listas com base em um critério condicional e associar dados temporais a cada ocorrência.<br>

# %%
# Área de código para o problema 3.3:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 4 - Ordem de Prioridade no Atendimento** 🔴
# Em um hospital, a ordem de atendimento respeita o nível de urgência do quadro clínico (Urgente, Grave, Normal, Leve). Pacientes com maior prioridade devem ser atendidos antes daqueles com menor prioridade.
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **Problema 4.1**
# Desenvolva um programa que simule a formação de uma fila de atendimento. O usuário deverá informar o nome e o nível de prioridade, e o programa deverá inserir o paciente na posição correta da fila.
#
# **🎯 Objetivo:** Implementar lógica de inserção ordenada em listas de acordo com prioridade customizada.<br>

# %%
# Área de código para o problema 4.1:

# %% [markdown]
# ### 📝 **Problema 4.2**
# Desenvolva um programa que consulte a fila de atendimento construída anteriormente e exiba separadamente os pacientes pertencentes a cada uma das quatro classificações de prioridade.
#
# **🎯 Objetivo:** Filtrar e agrupar elementos armazenados em uma estrutura de dados sequencial.<br>

# %%
# Área de código para o problema 4.2:

# %% [markdown]
# ### 📝 **Problema 4.3**
# Considere que cada nível de prioridade possui um tempo médio de atendimento definido. Desenvolva um programa que calcule o tempo total necessário para atender todos os pacientes presentes na fila.
#
# **🎯 Objetivo:** Calcular a soma cumulativa associando atributos dos objetos da fila a valores de referência.<br>

# %%
# Área de código para o problema 4.3:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 5 - Seleção de Participantes (Estudo sobre Parkinson)** 🟡
# Você está recrutando participantes. Os critérios são: idade >= 60 anos E ter diagnóstico/sintomas compatíveis com Parkinson. Adicionalmente, analisa-se o valor de um biomarcador.
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **Problema 5.1**
# Considerando uma coleção de fichas, desenvolva um programa que determine quantos pacientes atendem aos critérios necessários para participar do estudo.
#
# **🎯 Objetivo:** Aplicar filtros booleanos combinados (AND) sobre uma coleção de dados.<br>

# %%
# Área de código para o problema 5.1:

# %% [markdown]
# ### 📝 **Problema 5.2**
# Para os selecionados, classifique o biomarcador (<10: Baixo, 10-20: Moderado, >20: Alto). Desenvolva um programa que percorra os elegíveis e informe quantos estão em cada classe.
#
# **🎯 Objetivo:** Mapear e contar ocorrências utilizando faixas de valores (ranges).<br>

# %%
# Área de código para o problema 5.2:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 6 - Análise de Biomarcadores e Escalas Clínicas** 🟡
# Pesquisadores utilizam biomarcadores para identificar pacientes que necessitam de acompanhamento. Seu objetivo é automatizar esse processo analítico.
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **Problema 6.1**
# Em um estudo sobre Alzheimer, valores da proteína > 2,5 pg/mL indicam risco. Desenvolva um programa que percorra a lista de 6 pacientes, identifique os em risco, salve na lista `pacientes_em_risco` e conte-os.
#
# **🎯 Objetivo:** Filtrar listas salvando resultados em novas variáveis dinâmicas.<br>

# %%
# Área de código para o problema 6.1:

# %% [markdown]
# ### 📝 **Problema 6.2**
# Desenvolva uma função `classificar_depressao()` que receba um dicionário contendo nome e pontuação, e retorne a classificação dos sintomas: 0-4 (Sem sintomas), 5-9 (Leves), >= 10 (Moderados ou graves).
#
# **🎯 Objetivo:** Criar uma função customizada que manipule dados em estruturas de dicionário.<br>

# %%
# Área de código para o problema 6.2:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 7 - Monitoramento Contínuo de Culturas Celulares** 🟡
# Durante um experimento, acompanha-se diariamente a viabilidade celular. O objetivo é registrar e analisar as medições para decidir o futuro das culturas.
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **Problema 7.1**
# Desenvolva um programa que solicite ao usuário o percentual diário e guarde em uma lista. O cadastro deve continuar até a digitação de "fim".
#
# **🎯 Objetivo:** Criar um loop com condição de saída por string (sentinela).<br>

# %%
# Área de código para o problema 7.1:

# %% [markdown]
# ### 📝 **Problema 7.2**
# Após encerrar, apresente: quantidade de dias registrados, maior/menor percentual e média de viabilidade celular.
#
# **🎯 Objetivo:** Processar e exibir estatísticas sobre a lista recém-criada.<br>

# %%
# Área de código para o problema 7.2:

# %% [markdown]
# ### 📝 **Problema 7.3**
# Culturas com média < 70% devem ser descartadas. Desenvolva um programa que informe a decisão final baseada na viabilidade média calculada.
#
# **🎯 Objetivo:** Realizar validação final cruzada com um limite limiar de qualidade.<br>

# %%
# Área de código para o problema 7.3:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 8 - Análise do Sono Utilizando Smartwatches** 🟢
# Acompanhamento do número de horas dormidas durante 7 noites por um smartwatch. Os dados estão em uma tupla com 7 valores numéricos.
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **Problema 8.1**
# Desenvolva um programa que calcule a média de horas dormidas durante a semana a partir da tupla.
#
# **🎯 Objetivo:** Manipular e iterar sobre uma Tupla para obter somatórias e médias.<br>

# %%
# Área de código para o problema 8.1:

# %% [markdown]
# ### 📝 **Problema 8.2**
# Caso a média seja < 6, exiba "Alerta: Privação de sono detectada.". Caso contrário, "Padrão de sono adequado.".
#
# **🎯 Objetivo:** Condicional simples de resultado final.<br>

# %%
# Área de código para o problema 8.2:

# %% [markdown]
# ### 📝 **Problema 8.3**
# Desenvolva um programa que percorra a tupla e informe quantos dias o sono foi < 6h, o maior tempo e o menor tempo registrado.
#
# **🎯 Objetivo:** Encontrar valores extremos em estruturas de dados imutáveis.<br>

# %%
# Área de código para o problema 8.3:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 9 - Padronização de um Banco de Dados** 🟢
# Muitos registros manuais de medicamentos/exames possuem inconsistências e espaços sobrando. Precisamos higienizar os dados.
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **Problema 9.1**
# Dada uma lista de nomes manuais, desenvolva um programa que remova os espaços em branco do início e do final de cada registro.
#
# **🎯 Objetivo:** Aplicar funções de formatação de string, como o método `.strip()`.<br>

# %%
# Área de código para o problema 9.1:

# %% [markdown]
# ### 📝 **Problema 9.2**
# Modifique o programa para converter todos os nomes para letras minúsculas e salvar em `medicamentos_limpos`.
#
# **🎯 Objetivo:** Padronizar capitalização de texto para uso em sistemas case-sensitive.<br>

# %%
# Área de código para o problema 9.2:

# %% [markdown]
# ### 📝 **Problema 9.3**
# Identifique os registros repetidos após a limpeza e informe quantas vezes cada medicamento aparece na lista final.
#
# **🎯 Objetivo:** Computar frequências e criar uma contagem de ocorrências exclusivas.<br>

# %%
# Área de código para o problema 9.3:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 10 - Cadastro de Amostras Biológicas** 🟡
# Amostras biológicas (sangue, plasma ou saliva) precisam de rastreabilidade com volume, temperatura e código, tudo gerido por um sistema.
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **Problema 10.1**
# Desenvolva um programa que permita cadastrar diversas amostras biológicas, armazenando todas as informações fornecidas.
#
# **🎯 Objetivo:** Consolidar informações multifatoriais e repetitivas em uma lista de dicionários.<br>

# %%
# Área de código para o problema 10.1:

# %% [markdown]
# ### 📝 **Problema 10.2**
# Desenvolva um programa que permita consultar uma amostra pelo código e exibi-la de forma organizada.
#
# **🎯 Objetivo:** Criar lógica de busca unificada por chave de identificação (ID).<br>

# %%
# Área de código para o problema 10.2:

# %% [markdown]
# ### 📝 **Problema 10.3**
# Percorra todas as amostras e informe as quantidades registradas por tipo de material (sangue, plasma ou saliva).
#
# **🎯 Objetivo:** Efetuar agrupamentos baseados em categorias textuais (categorias de amostra).<br>

# %%
# Área de código para o problema 10.3:

# %% [markdown]
# ### 📝 **Problema 10.4**
# Determine qual amostra possui o maior volume armazenado e exiba todas as suas informações.
#
# **🎯 Objetivo:** Localizar um dicionário correspondente ao maior valor quantitativo associado.<br>

# %%
# Área de código para o problema 10.4:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 11 - Organização de Experimentos** 🔴
# Registros diários sobre culturas celulares, incluindo dados de responsável, placas, células cultivadas e viabilidade, necessários para um relatório final diário.
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **Problema 11.1**
# Desenvolva um programa que permita cadastrar os experimentos (nome, número de placas, quantidade de células, % de viabilidade).
#
# **🎯 Objetivo:** Rotina de entrada e manipulação massiva de dados associados a pesquisadores.<br>

# %%
# Área de código para o problema 11.1:

# %% [markdown]
# ### 📝 **Problema 11.2**
# Utilizando os experimentos cadastrados, calcule a média da viabilidade, a média do número de placas e a média da quantidade de células.
#
# **🎯 Objetivo:** Gerar métricas agregadas gerais da coleção inteira.<br>

# %%
# Área de código para o problema 11.2:

# %% [markdown]
# ### 📝 **Problema 11.3**
# Identifique e exiba todas as informações do experimento com maior viabilidade e o que utilizou o maior número de células.
#
# **🎯 Objetivo:** Extrair instâncias isoladas com base em picos de métricas variadas.<br>

# %%
# Área de código para o problema 11.3:

# %% [markdown]
# ### 📝 **Problema 11.4**
# Experimentos com viabilidade < 75% devem ser refeitos. Informe quantos devem ser refeitos e o nome dos respectivos responsáveis.
#
# **🎯 Objetivo:** Gerar relatório restritivo vinculando falhas na métrica diretamente ao usuário responsável.<br>

# %%
# Área de código para o problema 11.4:

# %% [markdown]
# ---

# %% [markdown]
# > ## 🔗 **Conteúdo extra**
# **Caso você queira praticar mais:**
# - Procure refatorar o seu código separando a lógica pesada em funções autossuficientes!
#
# **Referências e leituras extras:**
# - [Documentação Oficial do Python (pt-BR)](https://docs.python.org/pt-br/3/)
