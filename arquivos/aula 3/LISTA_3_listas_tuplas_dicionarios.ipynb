# %% [markdown]
# > # **Lista de exercícios — Aula 3**
#
# - **Professor:** Ryan Kevin
#   - al.ryan.felinto@impatech.org.br
#
# - **Monitores:**
#   - Bianca Abreu
#     - al.bianca.abreu@impatech.edu.br
#   - Bruno Paula
#     - al.bruno.paula@impatech.edu.br
#   - Gustavo Cardoso
#     - al.gustavo.cardoso@impatech.edu.br
#   - Pedro Alberti
#     - al.pedro.alberti@impatech.edu.br
#   - Cristiane Sampaio
#     - al.cristiane.sampaio@impatech.edu.br
#   - Lucas Barcelos
#     - al.lucas.barcelos@impatech.edu.br
#
# ---

# %% [markdown]
# > ## **Parte 1 — Acesso e análise de listas** 🟢
#
# Praticando índices, fatiamento, verificação de elementos e funções aplicadas a listas.

# %% [markdown]
# ### 📝 **Exercício 1 — Separando medições**
#
# Considere a lista de temperaturas fornecida na célula de código. Crie e exiba:
#
# - uma lista com as três primeiras temperaturas;
# - uma lista com as três últimas temperaturas;
# - uma lista com os elementos dos índices `2` até `5`, incluindo o índice `2` e excluindo o índice `6`;
# - uma cópia completa da lista original usando fatiamento.
#
# **🎯 Objetivo:** Praticar diferentes formas de fatiamento de listas.

# %%
# Área de código para o exercício 1:

temperaturas = [22.5, 23.1, 24.0, 25.3, 24.8, 23.9, 22.7]

# %% [markdown]
# ### 📝 **Exercício 2 — Pulando elementos**
#
# Considere a lista fornecida. Use fatiamento para criar e exibir:
#
# - uma lista contendo os elementos das posições pares;
# - uma lista contendo um elemento a cada três posições;
# - a lista completa na ordem inversa.
#
# **🎯 Objetivo:** Utilizar o terceiro parâmetro do fatiamento, chamado de passo.

# %%
# Área de código para o exercício 2:

dados = [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %% [markdown]
# ### 📝 **Exercício 3 — Resumo das amostras**
#
# Considere a lista de quantidades de Unidades Formadoras de Colônias (UFC). Exiba:
#
# - a quantidade de amostras;
# - o maior valor;
# - o menor valor;
# - a soma de todos os valores;
# - a média dos valores.
#
# Para calcular a média, utilize `sum()` e `len()`.
#
# **🎯 Objetivo:** Aplicar `len()`, `max()`, `min()` e `sum()` em uma lista numérica.

# %%
# Área de código para o exercício 3:

amostras_ufc = [50000, 72000, 68000, 91000, 45000, 83000]

# %% [markdown]
# ### 📝 **Exercício 4 — Valor presente ou ausente**
#
# Considere a lista de códigos fornecida. Verifique e exiba:
#
# - se o código `42` está na lista;
# - se o código `100` está na lista;
# - se o código `15` não está na lista.
#
# Utilize os operadores `in` e `not in`.
#
# **🎯 Objetivo:** Verificar a presença ou a ausência de elementos em uma lista.

# %%
# Área de código para o exercício 4:

codigos = [7, 15, 21, 42, 58, 73]

# %% [markdown]
# ### 📝 **Exercício 5 — Prevendo fatiamentos**
#
# Antes de executar a célula, escreva à direita de cada `#` o resultado que você espera obter.
#
# Depois, execute o código e confira suas respostas.
#
# **🎯 Objetivo:** Compreender os limites e o passo utilizados no fatiamento.

# %%
# Área de código para o exercício 5:

letras = ["a", "b", "c", "d", "e", "f", "g"]

print(letras[1:4])   #
print(letras[:3])    #
print(letras[4:])    #
print(letras[::2])   #
print(letras[::-1])  #
print(letras[:])     #

# %% [markdown]
# ---

# %% [markdown]
# > ## **Parte 2 — Métodos de listas** 🟢🟡
#
# Adicionando, removendo, procurando, ordenando e apagando elementos.

# %% [markdown]
# ### 📝 **Exercício 6 — Adicionando uma nova medição**
#
# Considere a lista de temperaturas fornecida. Peça ao usuário uma nova temperatura, converta-a para `float` e adicione-a ao final da lista usando `append()`.
#
# Exiba a lista antes e depois da alteração.
#
# **🎯 Objetivo:** Adicionar um único elemento ao final de uma lista.

# %%
# Área de código para o exercício 6:

temperaturas = [21.8, 22.4, 23.0, 22.7]

# %% [markdown]
# ### 📝 **Exercício 7 — Reunindo dados de dois dias**
#
# Adicione todos os elementos de `dados_terca` ao final de `dados_segunda` usando `extend()`.
#
# Depois, exiba as duas listas e verifique se `dados_terca` foi modificada.
#
# **🎯 Objetivo:** Acrescentar vários elementos a uma lista usando `extend()`.

# %%
# Área de código para o exercício 7:

dados_segunda = [45, 51, 48]
dados_terca = [53, 49, 56]

# %% [markdown]
# ### 📝 **Exercício 8 — Inserindo um paciente na ordem correta**
#
# A lista representa a ordem de atendimento de pacientes. Insira `"Carlos"` no índice `2`, sem substituir nenhum dos nomes existentes.
#
# Exiba a lista antes e depois da inserção.
#
# **🎯 Objetivo:** Inserir um elemento em uma posição específica usando `insert()`.

# %%
# Área de código para o exercício 8:

fila = ["Ana", "Bruno", "Daniel", "Eduarda"]

# %% [markdown]
# ### 📝 **Exercício 9 — Removendo pelo valor**
#
# A lista de resultados contém o valor inválido `-1` duas vezes.
#
# Use `remove()` uma vez e observe qual ocorrência é retirada. Em seguida, utilize `remove()` novamente para retirar a segunda ocorrência.
#
# Exiba a lista após cada remoção.
#
# **🎯 Objetivo:** Remover a primeira ocorrência de um valor usando `remove()`.

# %%
# Área de código para o exercício 9:

resultados = [12, -1, 18, 20, -1, 25]

# %% [markdown]
# ### 📝 **Exercício 10 — Retirando e armazenando elementos**
#
# Considere a lista de tarefas fornecida.
#
# 1. Use `pop(1)` para remover a tarefa de índice `1` e armazene o elemento removido em uma variável.
# 2. Use `pop()` para remover a última tarefa e também armazene o elemento removido.
# 3. Exiba os dois elementos removidos e a lista final.
#
# **🎯 Objetivo:** Remover elementos por posição e utilizar o valor retornado por `pop()`.

# %%
# Área de código para o exercício 10:

tarefas = ["organizar dados", "corrigir cadastro", "gerar gráfico", "enviar relatório"]

# %% [markdown]
# ### 📝 **Exercício 11 — Localizando e contando**
#
# Considere a lista de notas fornecida. Determine e exiba:
#
# - o índice da primeira ocorrência da nota `7`;
# - quantas vezes a nota `7` aparece;
# - quantas vezes a nota `10` aparece.
#
# Utilize `index()` e `count()`.
#
# **🎯 Objetivo:** Localizar a primeira ocorrência e contar repetições de um elemento.

# %%
# Área de código para o exercício 11:

notas = [8, 7, 9, 7, 6, 10, 7, 8]

# %% [markdown]
# ### 📝 **Exercício 12 — Ordenando e invertendo**
#
# Considere a lista de nomes fornecida.
#
# 1. Organize os nomes em ordem alfabética usando `sort()`.
# 2. Exiba a lista.
# 3. Inverta a ordem atual usando `reverse()`.
# 4. Exiba novamente a lista.
#
# **🎯 Objetivo:** Modificar a ordem dos elementos com `sort()` e `reverse()`.

# %%
# Área de código para o exercício 12:

nomes = ["Marina", "Ana", "Pedro", "Caio", "Bianca"]

# %% [markdown]
# ### 📝 **Exercício 13 — Limpando sem perder a cópia**
#
# Crie uma cópia de `registros` usando fatiamento. Depois:
#
# - use `clear()` para apagar todos os elementos da lista original;
# - exiba a lista original;
# - exiba a cópia.
#
# Explique, em um comentário, por que a cópia ainda possui os elementos.
#
# **🎯 Objetivo:** Utilizar `clear()` e perceber a diferença entre apagar uma lista e preservar uma cópia.

# %%
# Área de código para o exercício 13:

registros = ["A102", "A103", "A104", "A105"]

# %% [markdown]
# ### 📝 **Exercício 14 — Atualizando uma lista de amostras**
#
# Considere a lista fornecida e realize, nesta ordem:
#
# 1. adicione `72` ao final com `append()`;
# 2. acrescente `[81, 69]` com `extend()`;
# 3. insira `75` no índice `2`;
# 4. remova o valor `-1`;
# 5. retire o último elemento com `pop()` e armazene-o;
# 6. ordene a lista;
# 7. exiba a lista final, o elemento retirado, o menor valor, o maior valor e a soma.
#
# **🎯 Objetivo:** Combinar vários métodos e funções de listas em uma sequência de operações.

# %%
# Área de código para o exercício 14:

amostras = [64, 70, -1, 68, 77]

# %% [markdown]
# ---

# %% [markdown]
# > ## **Parte 3 — Tuplas** 🟡
#
# Observando as semelhanças e diferenças entre listas e tuplas.

# %% [markdown]
# ### 📝 **Exercício 15 — Acessando uma tupla**
#
# Considere a tupla que representa uma ficha de paciente. Exiba:
#
# - o nome;
# - a idade;
# - o último elemento usando índice negativo;
# - os três primeiros elementos por fatiamento;
# - uma cópia completa da tupla por fatiamento.
#
# **🎯 Objetivo:** Aplicar índices e fatiamento em tuplas.

# %%
# Área de código para o exercício 15:

paciente = ("Mariana", 31, 1.68, 62.5)

# %% [markdown]
# ### 📝 **Exercício 16 — Métodos válidos em tuplas**
#
# Considere a tupla de respostas. Utilize:
#
# - `count()` para descobrir quantas vezes `"sim"` aparece;
# - `count()` para descobrir quantas vezes `"não"` aparece;
# - `index()` para descobrir a posição da primeira ocorrência de `"talvez"`.
#
# **🎯 Objetivo:** Utilizar em tuplas os métodos `count()` e `index()`, que também são válidos para listas.

# %%
# Área de código para o exercício 16:

respostas = ("sim", "não", "sim", "talvez", "sim", "não")

# %% [markdown]
# ### 📝 **Exercício 17 — Analisando uma tupla numérica**
#
# Considere a tupla de medições. Exiba:
#
# - a quantidade de elementos;
# - o maior valor;
# - o menor valor;
# - a soma;
# - a média;
# - se o valor `18` pertence à tupla.
#
# Depois, tente alterar o primeiro elemento da tupla e observe a mensagem de erro. Em um comentário, explique a diferença entre listas e tuplas revelada pelo erro.
#
# **🎯 Objetivo:** Aplicar `len()`, `max()`, `min()`, `sum()` e `in` em tuplas e compreender sua imutabilidade.

# %%
# Área de código para o exercício 17:

medicoes = (12, 15, 18, 14, 20, 16)

# %% [markdown]
# ---

# %% [markdown]
# > ## **Parte 4 — Dicionários** 🟡
#
# Consultando chaves, valores e pares, além de remover informações.

# %% [markdown]
# ### 📝 **Exercício 18 — Conhecendo o cadastro**
#
# Considere o dicionário de um paciente. Exiba separadamente:
#
# - todas as chaves usando `.keys()`;
# - todos os valores usando `.values()`;
# - todos os pares de chave e valor usando `.items()`.
#
# **🎯 Objetivo:** Consultar as diferentes partes de um dicionário.

# %%
# Área de código para o exercício 18:

paciente = {
    "nome": "Rafael",
    "idade": 28,
    "altura": 1.50,
    "peso": 99.67
}

# %% [markdown]
# ### 📝 **Exercício 19 — Quantidade e presença de chaves**
#
# Utilizando o mesmo dicionário:
#
# - exiba a quantidade de pares com `len()`;
# - verifique se `"idade"` é uma chave do dicionário;
# - verifique se `"telefone"` é uma chave do dicionário;
# - verifique se o valor `"Rafael"` aparece entre os valores.
#
# **Atenção:** O operador `in`, quando usado diretamente em um dicionário, procura pelas **chaves**. Para procurar entre os valores, use `.values()`.
#
# **🎯 Objetivo:** Utilizar `len()` e `in` corretamente em dicionários.

# %%
# Área de código para o exercício 19:

paciente = {
    "nome": "Rafael",
    "idade": 28,
    "altura": 1.75,
    "peso": 73.4
}

# %% [markdown]
# ### 📝 **Exercício 20 — Removendo uma informação**
#
# O dicionário contém uma informação temporária chamada `"observacao"`.
#
# Use `.pop()` para:
#
# - remover essa chave;
# - armazenar o valor removido em uma variável;
# - exibir o valor removido;
# - exibir o dicionário atualizado.
#
# **🎯 Objetivo:** Remover um par de chave e valor usando `.pop()`.

# %%
# Área de código para o exercício 20:

exame = {
    "codigo": "EX-204",
    "paciente": "Luiza",
    "resultado": 8.7,
    "observacao": "revisar cadastro"
}

# %% [markdown]
# ### 📝 **Exercício 21 — Relatório de produto**
#
# Considere o dicionário fornecido. Percorra os pares retornados por `.items()` e exiba cada informação no formato:
#
# ```text
# nome: Álcool em gel
# quantidade: 18
# preco: 12.5
# ```
#
# Ao final, exiba a quantidade de informações armazenadas no dicionário.
#
# **🎯 Objetivo:** Percorrer os pares de um dicionário com `.items()`.

# %%
# Área de código para o exercício 21:

produto = {
    "nome": "Álcool em gel",
    "quantidade": 18,
    "preco": 12.5
}

# %% [markdown]
# ---

# %% [markdown]
# > ## **Parte 5 — Desafios integradores** 🔴
#
# Combinando listas, tuplas e dicionários para organizar e analisar dados.

# %% [markdown]
# ### 📝 **Exercício 22 — Resumo de um experimento**
#
# Considere a lista de resultados fornecida. Faça as seguintes operações:
#
# 1. adicione o resultado `82` com `append()`;
# 2. acrescente os resultados `[76, 91]` com `extend()`;
# 3. remova o valor inválido `-1`;
# 4. ordene os resultados;
# 5. crie um dicionário chamado `resumo` contendo:
#    - `"quantidade"`: número de resultados;
#    - `"menor"`: menor resultado;
#    - `"maior"`: maior resultado;
#    - `"soma"`: soma dos resultados;
#    - `"media"`: média dos resultados.
# 6. exiba todos os pares do dicionário usando `.items()`.
#
# **🎯 Objetivo:** Organizar resultados em uma lista e resumir as informações em um dicionário.

# %%
# Área de código para o exercício 22:

resultados = [73, 88, -1, 79, 84]

# %% [markdown]
# ### 📝 **Exercício 23 — Cadastro e remoção de participante**
#
# Considere o dicionário cujas chaves são códigos e cujos valores são tuplas contendo nome e idade.
#
# 1. Exiba todos os códigos cadastrados com `.keys()`.
# 2. Verifique se o código `"P03"` está cadastrado.
# 3. Use `.pop()` para remover o participante de código `"P02"` e armazene a tupla removida.
# 4. Exiba o nome e a idade do participante removido acessando os elementos da tupla.
# 5. Exiba os cadastros restantes usando `.items()`.
# 6. Exiba a quantidade final de participantes.
#
# **🎯 Objetivo:** Integrar dicionários e tuplas em uma estrutura de cadastro.

# %%
# Área de código para o exercício 23:

participantes = {
    "P01": ("Ana", 20),
    "P02": ("Bruno", 22),
    "P03": ("Carla", 19),
    "P04": ("Diego", 21)
}

# %% [markdown]
# ---

# %% [markdown]
# > ## **Parabéns por chegar até aqui!** 🎉
