# %% [markdown]
# > # **Exercícios - Aula X**
#
#  - Nome Professor responsável por essa aula
#     - E-mail do professor responsável
#  - Monitor 1
#     - E-mail do monitor 1
#  - Monitor 2
#     - E-mail do monitor 2
#
#  ## **Título da aula: conteúdo apresentado**
#
# ---

# %% [markdown]
# > ## **Problema 1 - Título do problema 1** 🟢 🟡 🔴
# Enunciado do problema 1 ; Contextualização ; **informações importantes devem ser destacadas**
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **Problema 1.y**
# Contextualização para o(s) problema(s) 1.y (1.1, 1.2, 1.3 e etc.)
#
# **🎯 Objetivo:** Objetivo do problema (o que deve ser feito?) <br>
# **📥 Exemplo de Entrada:** OPCIONAL<br>
# **📤 Exemplo de Saída:** OPCIONAL

# %%
# Área de código para o problema 1.y:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema X - Título do problema X** 🟢 🟡 🔴
# Enunciado do problema X (1, 2, 3, etc.) ; Contextualização ; **informações importantes devem ser destacadas**
#
# ### _obs: A cor da bolinha deve ser de acordo com a dificuldade (verde:fácil , amarelo:médio , vermelho:desafio)_

# %% [markdown]
# ### 📝 **_Problema x.y_**
# Contextualização para o(s) problema(s) x.y (1.1, 1.2, 2.1, 2.2, etc.)
#
# **🎯 Objetivo:** Objetivo do problema (o que deve ser feito?) <br>
# **📥 Exemplo de Entrada:** OPCIONAL<br>
# **📤 Exemplo de Saída:** OPCIONAL

# %%
# Área de código para o problema x.y:

# %% [markdown]
# ---

# %% [markdown]
# > ## 🔗 **Conteúdo extra**
# **Caso você queira praticar mais:**
# - [Exercício extra 1 (link)](https://exemplo.com)
# - [Exercício extra 2 (link)](https://exemplo.com)
#
# **Referências e leituras extras:**
# - [Link de material extra](https://exemplo.com)
