# %% [markdown]
# > # **Exercícios - Aula 3**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ry4n-felinto/impytech_2026/blob/main/aula_03/aula03_exercicios.ipynb)
#
# - **Professor:** Ryan Kevin
#   - al.ryan.felinto@impatech.edu.br
#
# - **Monitores:**
#   - Bianca Zavadisk
#     - al.bianca.abreu@impatech.edu.br
#   - Bruno Paula
#     - al.bruno.paula@impatech.edu.br
#   - Gustavo Cardoso
#     - al.gustavo.cardoso@impatech.edu.br
#   - Pedro Alberti
#     - al.pedro.alberti@impatech.edu.br
#   - Cristiane Sampaio
#     - al.cristiane.sampaio@impatech.edu.br
#
#  ## **Primeiras estruturas de dados e arquivos**
#
# ---

# %% [markdown]
# > ## **Problema 1 - Acesso e análise de listas** 🟢
# Praticando índices, fatiamento, verificação de elementos e funções aplicadas a listas.

# %% [markdown]
# ### 📝 **Problema 1.1**
# Considere a lista de temperaturas fornecida na célula de código. Crie e exiba:
# - uma lista com as três primeiras temperaturas;
# - uma lista com as três últimas temperaturas;
# - uma lista com os elementos dos índices `2` até `5`, incluindo o índice `2` e excluindo o índice `6`;
# - uma cópia completa da lista original usando fatiamento.
#
# **🎯 Objetivo:** Praticar diferentes formas de fatiamento de listas.<br>

# %%
# Área de código para o problema 1.1:

temperaturas = [22.5, 23.1, 24.0, 25.3, 24.8, 23.9, 22.7]

# %% [markdown]
# ### 📝 **Problema 1.2**
# Considere a lista fornecida. Use fatiamento para criar e exibir:
# - uma lista contendo os elementos das posições pares;
# - uma lista contendo um elemento a cada três posições;
# - a lista completa na ordem inversa.
#
# **🎯 Objetivo:** Utilizar o terceiro parâmetro do fatiamento, chamado de passo.<br>

# %%
# Área de código para o problema 1.2:

dados = [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %% [markdown]
# ### 📝 **Problema 1.3**
# Considere a lista de quantidades de Unidades Formadoras de Colônias (UFC). Exiba:
# - a quantidade de amostras;
# - o maior valor;
# - o menor valor;
# - a soma de todos os valores;
# - a média dos valores.
#
# **🎯 Objetivo:** Aplicar `len()`, `max()`, `min()` e `sum()` em uma lista numérica.<br>

# %%
# Área de código para o problema 1.3:

amostras_ufc = [50000, 72000, 68000, 91000, 45000, 83000]

# %% [markdown]
# ### 📝 **Problema 1.4**
# Considere a lista de códigos fornecida. Verifique e exiba se o código `42` está na lista; se o código `100` está na lista; se o código `15` não está na lista.
#
# **🎯 Objetivo:** Verificar a presença ou a ausência de elementos em uma lista.<br>

# %%
# Área de código para o problema 1.4:

codigos = [7, 15, 21, 42, 58, 73]

# %% [markdown]
# ### 📝 **Problema 1.5**
# Antes de executar a célula, escreva à direita de cada `#` o resultado que você espera obter. Depois, execute o código e confira suas respostas.
#
# **🎯 Objetivo:** Compreender os limites e o passo utilizados no fatiamento.<br>

# %%
# Área de código para o problema 1.5:

letras = ['a', 'b', 'c', 'd', 'e', 'f', 'g']

print(letras[1:4])   # 
print(letras[:3])    # 
print(letras[4:])    # 
print(letras[::2])   # 
print(letras[::-1])  # 
print(letras[:])     #

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 2 - Métodos de listas** 🟡
# Adicionando, removendo, procurando, ordenando e apagando elementos.

# %% [markdown]
# ### 📝 **Problema 2.1**
# Considere a lista de temperaturas fornecida. Peça ao usuário uma nova temperatura, converta-a para `float` e adicione-a ao final da lista usando `append()`. Exiba a lista antes e depois da alteração.
#
# **🎯 Objetivo:** Adicionar um único elemento ao final de uma lista.<br>

# %%
# Área de código para o problema 2.1:

temperaturas = [21.8, 22.4, 23.0, 22.7]

# %% [markdown]
# ### 📝 **Problema 2.2**
# Adicione todos os elementos de `dados_terca` ao final de `dados_segunda` usando `extend()`. Depois, exiba as duas listas e verifique se `dados_terca` foi modificada.
#
# **🎯 Objetivo:** Acrescentar vários elementos a uma lista usando `extend()`.<br>

# %%
# Área de código para o problema 2.2:

dados_segunda = [45, 51, 48]
dados_terca = [53, 49, 56]

# %% [markdown]
# ### 📝 **Problema 2.3**
# A lista representa a ordem de atendimento de pacientes. Insira `"Carlos"` no índice `2`, sem substituir nenhum dos nomes existentes. Exiba a lista antes e depois da inserção.
#
# **🎯 Objetivo:** Inserir um elemento em uma posição específica usando `insert()`.<br>

# %%
# Área de código para o problema 2.3:

fila = ['Ana', 'Bruno', 'Daniel', 'Eduarda']

# %% [markdown]
# ### 📝 **Problema 2.4**
# A lista de resultados contém o valor inválido `-1` duas vezes. Use `remove()` uma vez e observe qual ocorrência é retirada. Em seguida, utilize `remove()` novamente para retirar a segunda ocorrência.
#
# **🎯 Objetivo:** Remover a primeira ocorrência de um valor usando `remove()`.<br>

# %%
# Área de código para o problema 2.4:

resultados = [12, -1, 18, 20, -1, 25]

# %% [markdown]
# ### 📝 **Problema 2.5**
# Considere a lista de tarefas fornecida.
# 1. Use `pop(1)` para remover a tarefa de índice `1` e armazene-a.
# 2. Use `pop()` para remover a última tarefa e armazene-a.
# 3. Exiba os dois elementos removidos e a lista final.
#
# **🎯 Objetivo:** Remover elementos por posição e utilizar o valor retornado por `pop()`.<br>

# %%
# Área de código para o problema 2.5:

tarefas = ['organizar dados', 'corrigir cadastro', 'gerar gráfico', 'enviar relatório']

# %% [markdown]
# ### 📝 **Problema 2.6**
# Considere a lista de notas fornecida. Determine e exiba: o índice da primeira ocorrência da nota `7`; quantas vezes a nota `7` aparece; quantas vezes a nota `10` aparece.
#
# **🎯 Objetivo:** Localizar a primeira ocorrência e contar repetições de um elemento.<br>

# %%
# Área de código para o problema 2.6:

notas = [8, 7, 9, 7, 6, 10, 7, 8]

# %% [markdown]
# ### 📝 **Problema 2.7**
# Considere a lista de nomes fornecida. Organize os nomes em ordem alfabética usando `sort()` e exiba a lista. Depois, inverta a ordem atual usando `reverse()` e exiba novamente.
#
# **🎯 Objetivo:** Modificar a ordem dos elementos com `sort()` e `reverse()`.<br>

# %%
# Área de código para o problema 2.7:

nomes = ['Marina', 'Ana', 'Pedro', 'Caio', 'Bianca']

# %% [markdown]
# ### 📝 **Problema 2.8**
# Crie uma cópia de `registros` usando fatiamento. Depois, use `clear()` para apagar todos os elementos da lista original. Exiba a original e a cópia. Explique o motivo de a cópia ainda possuir os elementos.
#
# **🎯 Objetivo:** Utilizar `clear()` e perceber a diferença entre apagar uma lista e preservar uma cópia.<br>

# %%
# Área de código para o problema 2.8:

registros = ['A102', 'A103', 'A104', 'A105']

# %% [markdown]
# ### 📝 **Problema 2.9**
# Considere a lista fornecida e realize as seguintes operações na ordem: adicione `72` ao final; acrescente `[81, 69]`; insira `75` no índice `2`; remova `-1`; retire o último elemento com `pop()` e armazene-o; ordene a lista. Exiba tudo ao final.
#
# **🎯 Objetivo:** Combinar vários métodos e funções de listas em uma sequência.<br>

# %%
# Área de código para o problema 2.9:

amostras = [64, 70, -1, 68, 77]

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 3 - Tuplas** 🟡
# Observando as semelhanças e diferenças entre listas e tuplas.

# %% [markdown]
# ### 📝 **Problema 3.1**
# Considere a tupla que representa uma ficha de paciente. Exiba: o nome; a idade; o último elemento por índice negativo; os três primeiros elementos por fatiamento; uma cópia completa.
#
# **🎯 Objetivo:** Aplicar índices e fatiamento em tuplas.<br>

# %%
# Área de código para o problema 3.1:

paciente = ('Mariana', 31, 1.68, 62.5)

# %% [markdown]
# ### 📝 **Problema 3.2**
# Considere a tupla de respostas. Descubra quantas vezes `"sim"` aparece, quantas vezes `"não"` aparece e a posição da primeira ocorrência de `"talvez"`.
#
# **🎯 Objetivo:** Utilizar em tuplas os métodos `count()` e `index()`.<br>

# %%
# Área de código para o problema 3.2:

respostas = ('sim', 'não', 'sim', 'talvez', 'sim', 'não')

# %% [markdown]
# ### 📝 **Problema 3.3**
# Considere a tupla de medições. Exiba: quantidade, maior valor, menor valor, soma, média e se o valor `18` pertence à tupla. Depois, tente alterar o primeiro elemento e explique o erro em um comentário.
#
# **🎯 Objetivo:** Aplicar `len()`, `max()`, `min()`, `sum()` e `in` em tuplas e compreender sua imutabilidade.<br>

# %%
# Área de código para o problema 3.3:

medicoes = (12, 15, 18, 14, 20, 16)

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 4 - Dicionários** 🟡
# Consultando chaves, valores e pares, além de remover informações.

# %% [markdown]
# ### 📝 **Problema 4.1**
# Considere o dicionário de um paciente. Exiba separadamente todas as chaves, todos os valores e todos os pares de chave e valor.
#
# **🎯 Objetivo:** Consultar as diferentes partes de um dicionário.<br>

# %%
# Área de código para o problema 4.1:

paciente = {
    'nome': 'Rafael',
    'idade': 28,
    'altura': 1.50,
    'peso': 99.67
}

# %% [markdown]
# ### 📝 **Problema 4.2**
# Utilizando o dicionário fornecido: exiba a quantidade de pares; verifique se `"idade"` é chave; verifique se `"telefone"` é chave; verifique se o valor `"Rafael"` aparece.
#
# **🎯 Objetivo:** Utilizar `len()` e `in` corretamente em dicionários.<br>

# %%
# Área de código para o problema 4.2:

paciente = {
    'nome': 'Rafael',
    'idade': 28,
    'altura': 1.75,
    'peso': 73.4
}

# %% [markdown]
# ### 📝 **Problema 4.3**
# O dicionário contém uma informação temporária chamada `"observacao"`. Use `.pop()` para remover essa chave, armazenar o valor removido e exibir tanto o valor quanto o dicionário atualizado.
#
# **🎯 Objetivo:** Remover um par de chave e valor usando `.pop()`.<br>

# %%
# Área de código para o problema 4.3:

exame = {
    'codigo': 'EX-204',
    'paciente': 'Luiza',
    'resultado': 8.7,
    'observacao': 'revisar cadastro'
}

# %% [markdown]
# ### 📝 **Problema 4.4**
# Considere o dicionário fornecido. Percorra os pares retornados por `.items()` e exiba cada informação no formato `chave: valor`. Ao final, exiba a quantidade de informações armazenadas.
#
# **🎯 Objetivo:** Percorrer os pares de um dicionário com `.items()`.<br>

# %%
# Área de código para o problema 4.4:

produto = {
    'nome': 'Álcool em gel',
    'quantidade': 18,
    'preco': 12.5
}

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 5 - Desafios integradores** 🔴
# Combinando listas, tuplas e dicionários para organizar e analisar dados.

# %% [markdown]
# ### 📝 **Problema 5.1**
# Considere a lista de resultados fornecida. Faça as operações: adicione `82`; acrescente `[76, 91]`; remova `-1`; ordene os resultados. Crie um dicionário resumido com quantidade, menor, maior, soma e média. Exiba os pares do dicionário.
#
# **🎯 Objetivo:** Organizar resultados em uma lista e resumir as informações em um dicionário.<br>

# %%
# Área de código para o problema 5.1:

resultados = [73, 88, -1, 79, 84]

# %% [markdown]
# ### 📝 **Problema 5.2**
# Considere o dicionário cujas chaves são códigos e cujos valores são tuplas contendo nome e idade. Exiba todos os códigos; verifique se `"P03"` está cadastrado; use `.pop()` para remover `"P02"` e exiba seu nome e idade; exiba os cadastros restantes e a quantidade final.
#
# **🎯 Objetivo:** Integrar dicionários e tuplas em uma estrutura de cadastro.<br>

# %%
# Área de código para o problema 5.2:

participantes = {
    'P01': ('Ana', 20),
    'P02': ('Bruno', 22),
    'P03': ('Carla', 19),
    'P04': ('Diego', 21)
}

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema 6 - Manipulação de Arquivos** 🟡

# %% [markdown]
# ### 📝 **Problema 6.1**
# Você recebeu um arquivo chamado `triagem_pacientes.txt` contendo o nome dos pacientes que chegaram ao pronto-socorro. Leia esse arquivo e armazene os nomes em uma lista, exibindo quantos pacientes estão na espera.
#
# **🎯 Objetivo:** Praticar a leitura de arquivos e o armazenamento de dados em listas.<br>
# **📥 Exemplo de Entrada:** `triagem_pacientes.txt`<br>
# **📤 Exemplo de Saída:** `Total de pacientes em espera: 4`

# %%
# Área de código para o problema 6.1:

# %% [markdown]
# ### 📝 **Problema 6.2**
# Crie um programa que pegue uma lista de dicionários com resultados de exames (`nome_paciente`, `glicemia`) e escreva esses resultados em um arquivo chamado `resultados_exames.txt`. Cada linha deve conter: `Nome: [nome] | Glicemia: [valor] mg/dL`.
#
# **🎯 Objetivo:** Aprender a manipular dados e escrevê-los em arquivo (`modo w`).<br>
# **📥 Exemplo de Entrada:** `[{'nome': 'Ana', 'glicemia': 90}, {'nome': 'Bruno', 'glicemia': 110}]`<br>
# **📤 Exemplo de Saída:** Arquivo `resultados_exames.txt` criado com as linhas formatadas.

# %%
# Área de código para o problema 6.2:

lista_exames = [{'nome': 'Ana', 'glicemia': 90}, {'nome': 'Bruno', 'glicemia': 110}]

# %% [markdown]
# ### 📝 **Problema 6.3**
# Um novo paciente chegou tardiamente e seu resultado de exame precisa ser incluído no arquivo `resultados_exames.txt` gerado anteriormente. Adicione o paciente `Carlos` com glicemia `95` ao final do arquivo, sem apagar os pacientes anteriores.
#
# **🎯 Objetivo:** Utilizar o modo `a` (append) para atualizar arquivos de registro.<br>
# **📥 Exemplo de Entrada:** `Carlos`, `95`<br>
# **📤 Exemplo de Saída:** O arquivo `resultados_exames.txt` agora contém três linhas.

# %%
# Área de código para o problema 6.3:

novo_paciente = "Carlos"
nova_glicemia = 95

# %% [markdown]
# ---

# %% [markdown]
# > ## 🔗 **Conteúdo extra**
#
# **Caso você queira praticar mais:**
#
# - [Python Brasil (Portal Dunossauro)](https://exercicios.dunossauro.com/)
#     - Listas: exercícios **01 a 15**
#     - Strings: exercícios **01 a 08**
#     - Manipulação de arquivos: exercícios **01 e 02**
#
# - [ISQUICHA, Exercícios de Lógica Python](https://github.com/isquicha/exercicios-logica-python)
#     - Exercícios **076 a 090**
#     - Exercícios **101 a 106**
#
# **Referências e leituras extras:**
#
# - **Livro de referência (1):** [Pense em Python](https://penseallen.github.io/PensePython2e/)
#     - Capítulos **7 e 14**
# - **Livro de referência (2):** [Python for data analysis](https://wesmckinney.com/book/)
#     - Capítulo **3**
# - **Documentação oficial do Python (em inglês):** [Estruturas de dados](https://docs.python.org/3/tutorial/datastructures.html) e [Leitura e escrita de arquivos](https://www.google.com/search?q=https://docs.python.org/3/tutorial/inputoutput.html%23reading-and-writing-files)
