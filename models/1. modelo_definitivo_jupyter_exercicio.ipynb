# %% [markdown]
# > # **Exercícios - Aula X**
#
#  - Nome Professor responsável por essa aula
#     - E-mail do professor responsável
#  - Monitor 1
#     - E-mail do monitor 1
#  - Monitor 2
#     - E-mail do monitor 2
#
#  ## **Título da aula: conteúdo apresentado**
#
# ---

# %% [markdown]
# > ## **Problema 1 - Título do problema 1**
# Enunciado do problema 1 ; Contextualização ; **informações importantes devem ser destacadas**

# %% [markdown]
# ### **Problema 1.y**
# Requisito / Enunciado para o(s) problema(s) 1.y (1.1, 1.2, 1.3 e etc.)

# %%
# Objetivo: o que fazer pra resolver esse problema?
# Exemplos (opcional)

# Área de código para o problema 1.y:

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema X - Título do problema X**
# Enunciado do problema X (1, 2, 3, etc.) ; Contextualização ; **informações importantes devem ser destacadas**

# %% [markdown]
# ### **_Problema x.y_**
# Requisito / Enunciado para o(s) problema(s) x.y (1.1, 1.2, 2.1, 2.2, etc.)

# %%
# Objetivo: o que fazer pra resolver esse problema?
# Exemplos (opcional)

# Área de código para o problema x.y:
