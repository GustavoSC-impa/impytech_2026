# %% [markdown]
# > # **Resolução - Exercício X (Aula X)**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ry4n-felinto/impytech_2026/blob/main/arquivos/aula%20#/aula0#_gabarito.ipynb)
#
#  - Nome Professor responsável por essa aula
#     - E-mail do professor responsável
#  - Monitor 1
#     - E-mail do monitor 1
#  - Monitor 2
#     - E-mail do monitor 2
#
#  ## **Título da aula referente: conteúdo apresentado**
#
# ---

# %% [markdown]
# > ## **Problema 1 - Título do problema 1** 🟢 🟡 🔴
# Enunciado do problema 1, o mesmo que está no exercício

# %% [markdown]
# ### ✅ **Resolução — Problema 1.y**
# Contextualização do problema 1.y (1.1, 1.2, 1.3, ...), exatamente como está no exercício
#
# **🎯 Objetivo:** Objetivo do problema (o que deve ser feito?) <br>
#
# **🧠 Explicação lógica: (opcional)**<br>
# Explicação da lógica envolvida na resolução

# %%
"""
Podem ter comentários (usando aspas triplas para destacar) ao longo do código de solução
Tente comentar cada conjunto de passos
"""
# Out:
# '\nPodem ter comentários (usando aspas triplas para destacar) ao longo do código de solução\nTente comentar cada conjunto de passos\n'

# %% [markdown]
# Alguma outra informação/explicação adicional

# %%
# Algum outro bloco de código adicional para explicação

# %% [markdown]
# ---

# %% [markdown]
# > ## **Problema X - Título do problema X** 🟢 🟡 🔴
# Contextualização do problema X (1, 2, 3, etc.) exatamente como está no exercício

# %% [markdown]
# ### ✅ **Resolução — Problema x.y**
# Enunciado do(s) problema(s) x.y (1.1, 1.2, 2.1, 2.2, etc.), como está no exercício
#
# **🎯 Objetivo:** Objetivo do problema (o que deve ser feito?) <br>
#
# **🧠 Explicação lógica: (opcional)**<br>
# Explicação da lógica envolvida na resolução

# %%
"""
Podem ter comentários (usando aspas triplas para destacar) ao longo do código de solução
"""

# %% [markdown]
# Alguma outra informação/explicação adicional

# %%
# Algum outro bloco de código adicional para explicação
