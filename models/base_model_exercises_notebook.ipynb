# %% [markdown]
# # Exercícios - Aula X
#
# (Professor responsável por essa aula)
# (Talvez contato para ajudar os alunos assincronizadamente)
#
# (Nome da Aula): (O que aprendemos nessa aula)

# %% [markdown]
# ## Problema 1 - Classificação por IMC (EXERCÍCIO EXEMPO)
# Durante uma avaliação nutricional, você está atendendo um paciente chamado **João Paulo**, que tem **37** anos de idade, pesa **78kg** e possui **1.78** de altura. João está aguardando para saber o seu **índice de massa corporal (IMC)**. Para agilizar o serviço, você decide usar Python para criar um programa para salvar os dados do paciente, e seus resultados
#
# **(DESTAQUEM AS INFORMAÇÕES IMPORTANTES DO ENUNCIADO)**

# %% [markdown]
# ### Problema 1.1
# Declare as variáveis e atribua seus valores.

# %%
# Objetivo: Declare uma variável e atribua seus respectivos valores
# EXEMPLO:
# nome = "João Paulo"

# %% [markdown]
# ### Problema 1.2
# Realize o cálculo do IMC com as variáveis declaradas.

# %%
# TODO: Implemente as contas para calcular o IMC e armazene em uma variável
# imc = ...

# %% [markdown]
# ### Problema 1.3
# Através da tabela abaixo e o valor do IMC calculado na célula anterior, declare uma variável e armazene o valor da classificação.
#
# | IMC | Classificações |
# | :--- | :--- |
# | Menor do que 18,5 | Abaixo do peso normal |
# | 18,5 - 24,9 | Peso normal |
# | 25,0 - 29,9 | Excesso de peso |
# | 30,0 - 34,9 | Obesidade classe I |
# | 35,0 - 39,9 | Obesidade classe II |
# | Maior ou igual a 40,0 | Obesidade classe III |

# %%
# TODO: Crie a estrutura condicional para definir a classificação baseada no IMC
# EXEMPLO:
# if imc < 18.5:
#   classificacao = \"Abaixo do peso normal

# %% [markdown]
# ### Problema 1.4
# Mostre na tela cada variável criada ao longo do exercício com a função `print`.

# %%
# TODO: Use a função print para mostrar as variáveis
# EXEMPLO:
# print(f"Nome do paciente: {nome}")

# %% [markdown]
# # Bibliografia adicional (EXEMPLO)
#
# - MENDES, Eduardo, **Exercícios: Estrutura Sequencial**:
#   - Exercícios **1-6**, **15** e **18**
# - DOWNEY, Allen B. **Pense em Python. 2ª ed.** São Paulo: Novatec Editora, 2016:
#   - Capítulo 1 ; Exercício **1.2**
#   - Capítulo 2 ; Exercício **2.2**
