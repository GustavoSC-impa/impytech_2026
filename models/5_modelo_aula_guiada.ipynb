# %% [markdown]
# > # **Aula Guiada - Aula X**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ry4n-felinto/impytech_2026/blob/main/arquivos/aula%20#/aula0#_notebook_guiado.ipynb)
#
#  - Nome Professor responsável por essa aula
#     - E-mail do professor responsável
#  - Monitor 1
#     - E-mail do monitor 1
#  - Monitor 2
#     - E-mail do monitor 2
#
#  ## **Título da aula: conteúdo apresentado**
#
# ---

# %% [markdown]
# > ## **Conceito X - Título do conceito**
# Descrição do conceito apresentado ; Contextualização teórica ; **informações importantes devem ser destacadas**
#
# > **O que vamos aprender:**
# > - Ponto de aprendizado 1
# > - Ponto de aprendizado 2
# > - Ponto de aprendizado 3

# %% [markdown]
# ### **Passo X.y — Título do passo**
# Explicação do que será feito neste passo e **por que** é importante.

# %%
# =============================================
# PASSO X.y — Título do passo
# =============================================
# Explicação linha a linha do que o código faz

# [PARTE 1] — Descrição da primeira parte
variavel_exemplo = "valor"      # comentário explicando essa linha

# [PARTE 2] — Descrição da segunda parte
# resultado = funcao(variavel_exemplo)  # ← descomente e complete aqui

# [PARTE 3] — Exibindo o resultado
print(variavel_exemplo)         # exibe o resultado na tela

# descrição do que o aluno deve tentar sozinho

# %% [markdown]
# > 📝 **Explicação do código acima:**
# > - `variavel_exemplo` → descreva o papel da variável
# > - `funcao()` → descreva o que a função faz
# > - **Ponto de atenção:** destaque algum detalhe importante

# %% [markdown]
# ---

# %% [markdown]
# > ## **Conceito Y - Título do próximo conceito**
# Descrição do conceito Y ; Contextualização ; **informações importantes devem ser destacadas**
#
# > **O que vamos aprender:**
# > - Ponto de aprendizado 1
# > - Ponto de aprendizado 2

# %% [markdown]
# ### **Passo Y.y — Título do passo**
# Explicação do que será feito neste passo.

# %%
# =============================================
# PASSO Y.y — Título do passo
# =============================================

# [PARTE 1] — Descrição
# seu código aqui...

# [PARTE 2] — Descrição
# seu código aqui...

#   AGORA É SUA VEZ: descrição do desafio para o aluno

# %% [markdown]
# > **Explicação do código acima:**
# > - Ponto explicativo 1
# > - Ponto explicativo 2
# > - **Ponto de atenção:** destaque algum detalhe importante
#
# ---

# %% [markdown]
# > ## **Resumo da Aula**
# > Nesta aula, você aprendeu:
# > - **Conceito X:** resumo em uma linha
# > - **Conceito Y:** resumo em uma linha
# >
# > 🔗 **Referências e leituras extras:**
# > - [Link de documentação ou material extra](https://link.exemplo.com)
